# %% [markdown]
# # StartUps.vet

# %% [markdown]
# ### Quick Introduction

# %% [markdown]
# The following data sets have been scraped from `startups.vet/companies` and from `vip.vetbiz.gov/Public/Search/Default.aspx`.
#
# Both data sets require some cleaning up before they can be comfortably analyzed.

# %% [markdown]
# ### Data

# %%
import pandas as pd
# Out:
# '/home/ron/dev/startups.vet'

# %%
startups_data = pd.read_csv('scanners/csv_files/startups_data.csv')

# %%
startups_data.head(5)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Website</th>
#       <th>Employees</th>
#       <th>Total Funding</th>
#       <th>Stage</th>
#       <th>Year Founded</th>
#       <th>Organization Affiliation</th>
#       <th>Total Founders</th>
#       <th>Veteran Founders</th>
#       <th>Veteran Executives</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>AgentHero</td>
#       <td>NaN</td>
#       <td>k</td>
#       <td>NaN</td>
#       <td>2015</td>
#       <td>Patriot Boot Camp</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Akouba Credit</td>
#       <td>NaN</td>
#       <td>k</td>
#       <td>NaN</td>
#       <td>2015</td>
#       <td>Bunker</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Andela</td>
# ...

# %%
vetbiz_data = pd.read_csv('scanners/csv_files/vetbiz_data.csv')

# %%
vetbiz_data.head(5)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Duns</th>
#       <th>BusinessName</th>
#       <th>DbaName</th>
#       <th>City</th>
#       <th>State</th>
#       <th>Phone</th>
#       <th>CompanyEmail</th>
#       <th>WebSite</th>
#       <th>LastVerified</th>
#       <th>ExpirationDate</th>
#       <th>...</th>
#       <th>Naics</th>
#       <th>Fsc</th>
#       <th>Psc</th>
#       <th>GeographicalServiceArea</th>
#       <th>CommercialContracts</th>
#       <th>DodContracts</th>
#       <th>FSS</th>
#       <th>LastModified</th>
#       <th>MentorProtege</th>
#       <th>JointVenture</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>78705297</td>
#       <td>Eugene Robinson</td>
#       <td>Anadine Design Management</td>
#       <td>Buffalo</td>
#       <td>NY</td>
#       <td>7165636156</td>
#       <td>anadine51@yahoo.com</td>
#       <td>NaN</td>
# ...
